# %% [markdown]
# # This is the first part of the assignment. You will see the second part below.

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', na_values = 'Not assigned', flavor = 'html5lib')

# %%
print(type(df[0]))
df = df[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.columns
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
df.rename({0: 'Postcode', 1: 'Borough', 2: 'Neighbourhood'}, axis = 'columns', inplace = True)

# %%
print(df.isnull().sum())
df.drop(df.index[0], inplace = True)
df.dropna(axis = 0, inplace = True)
print(df.isnull().sum())
df
# Out:
# Postcode          0
# Borough          77
# Neighbourhood    78
# dtype: int64
# Postcode         0
# Borough          0
# Neighbourhood    0
# dtype: int64
#     Postcode           Borough  \
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 7        M6A        North York
# 8        M6A        North York
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 13       M1B       Scarborough
# 15       M3B        North York
# 16       M4B         East York
# 17       M4B         East York
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 20       M6B        North York
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M9B         Etobicoke
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 30       M1C       Scarborough
# 32       M3C        North York
# ...

# %% [markdown]
# # There are 211 rows and 3 columns in the df.

# %% [markdown]
# # Second part of the assignment starts here:

# %%
geo_data = pd.read_csv('http://cocl.us/Geospatial_data')
geo_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo_data.shape
# Out:
# (103, 3)

# %%
merged_inner = pd.merge(left=df,right=geo_data, left_on='Postcode', right_on='Postal Code')

merged_inner
# what's the size of the output data?
new_df=merged_inner.drop(['Postal Code'], axis=1)
new_df
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M5A  Downtown Toronto
# 4        M6A        North York
# 5        M6A        North York
# 6        M9A         Etobicoke
# 7        M1B       Scarborough
# 8        M1B       Scarborough
# 9        M3B        North York
# 10       M4B         East York
# 11       M4B         East York
# 12       M5B  Downtown Toronto
# 13       M5B  Downtown Toronto
# 14       M6B        North York
# 15       M9B         Etobicoke
# 16       M9B         Etobicoke
# 17       M9B         Etobicoke
# 18       M9B         Etobicoke
# 19       M9B         Etobicoke
# 20       M1C       Scarborough
# 21       M1C       Scarborough
# 22       M1C       Scarborough
# 23       M3C        North York
# 24       M3C        North York
# 25       M4C         East York
# 26       M5C  Downtown Toronto
# 27       M6C              York
# 28       M9C         Etobicoke
# ...

# %% [markdown]
# # End of part 2.
